# %%
from pybaseball import statcast, pitching_stats, batting_stats
from pandas import Series
from sqlalchemy import *
import MySQLdb

# %%
batting = batting_stats(2017, 2017)

# %%
batting.dtypes
# Out:
# Season             float64
# Name                object
# Team                object
# Age                float64
# G                  float64
# AB                 float64
# PA                 float64
# H                  float64
# 1B                 float64
# 2B                 float64
# 3B                 float64
# HR                 float64
# R                  float64
# RBI                float64
# BB                 float64
# IBB                float64
# SO                 float64
# HBP                float64
# SF                 float64
# SH                 float64
# GDP                float64
# SB                 float64
# CS                 float64
# AVG                float64
# GB                 float64
# FB                 float64
# LD                 float64
# IFFB               float64
# Pitches            float64
# Balls              float64
#                     ...
# wCH (pi)           float64
# wCS (pi)           float64
# wCU (pi)           float64
# wFA (pi)           float64
# wFC (pi)           float64
# wFS (pi)           float64
# wKN (pi)           float64
# wSB (pi)           float64
# wSI (pi)           float64
# wSL (pi)           float64
# wXX (pi)           float64
# wCH/C (pi)         float64
# wCS/C (pi)         float64
# wCU/C (pi)         float64
# wFA/C (pi)         float64
# wFC/C (pi)         float64
# wFS/C (pi)         float64
# wKN/C (pi)         float64
# wSB/C (pi)         float64
# wSI/C (pi)         float64
# wSL/C (pi)         float64
# wXX/C (pi)         float64
# O-Swing% (pi)      float64
# Z-Swing% (pi)      float64
# Swing% (pi)        float64
# O-Contact% (pi)    float64
# Z-Contact% (pi)    float64
# Contact% (pi)      float64
# Zone% (pi)         float64
# Pace (pi)          float64
# Length: 287, dtype: object

# %%
for key, value in batting.dtypes.to_dict().iteritems():
    print str('Column("' + str(key) + '", ' + str(value) + ', nullable=True),')
# Out:
# Column("UN% (pfx)", float64, nullable=True),
# Column("wCH (pi)", float64, nullable=True),
# Column("KC-X (pfx)", float64, nullable=True),
# Column("FC-Z (pfx)", float64, nullable=True),
# Column("BB", float64, nullable=True),
# Column("wKN", float64, nullable=True),
# Column("wCH/C (pfx)", float64, nullable=True),
# Column("wKC (pfx)", float64, nullable=True),
# Column("Hard%", float64, nullable=True),
# Column("wCH/C (pi)", float64, nullable=True),
# Column("BU", float64, nullable=True),
# Column("FC-Z (pi)", float64, nullable=True),
# Column("Oppo%", float64, nullable=True),
# Column("vSC (pfx)", float64, nullable=True),
# Column("wSL (pfx)", float64, nullable=True),
# Column("wCU (pfx)", float64, nullable=True),
# Column("SF%", float64, nullable=True),
# Column("HBP", float64, nullable=True),
# Column("pLI", float64, nullable=True),
# Column("FA-X (pi)", float64, nullable=True),
# Column("vSI (pi)", float64, nullable=True),
# Column("vFA (pfx)", float64, nullable=True),
# Column("FS% (pi)", float64, nullable=True),
# Column("CH%", float64, nullable=True),
# Column("Zone%", float64, nullable=True),
# Column("wSF", float64, nullable=True),
# Column("SL-Z (pfx)", float64, nullable=True),
# Column("wFC/C (pi)", float64, nullable=True),
# Column("KN%", float64, nullable=True),
# Column("wFC (pfx)", float64, nullable=True),
# Column("wSL", float64, nullable=True),
# Column("Strikes", float64, nullable=True),
# Column("GB/FB", float64, nullable=True),
# Column("wFT (pfx)", float64, nullable=True),
# Column("RAR", float64, nullable=True),
# Column("wSI (pfx)", float64, nullable=True),
# Column("FS-X (pfx)", float64, nullable=True),
# Column("SI-X (pi)", float64, nullable=True),
# Column("SL-X (pfx)", float64, nullable=True),
# Column("SB-Z (pi)", float64, nullable=True),
# Column("vFA (pi)", float64, nullable=True),
# Column("vFC (pfx)", float64, nullable=True),
# Column("Bat", float64, nullable=True),
# Column("CS% (pi)", float64, nullable=True),
# Column("wFA/C (pi)", float64, nullable=True),
# Column("Med%", float64, nullable=True),
# Column("SFv", float64, nullable=True),
# Column("H", float64, nullable=True),
# Column("Def", float64, nullable=True),
# Column("KN% (pfx)", float64, nullable=True),
# Column("SB% (pi)", float64, nullable=True),
# Column("wFA/C (pfx)", float64, nullable=True),
# Column("FO% (pfx)", float64, nullable=True),
# Column("GB", float64, nullable=True),
# Column("2B", float64, nullable=True),
# Column("Swing% (pfx)", float64, nullable=True),
# Column("vEP (pfx)", float64, nullable=True),
# Column("wCH (pfx)", float64, nullable=True),
# Column("vFT (pfx)", float64, nullable=True),
# Column("FA-Z (pi)", float64, nullable=True),
# Column("CU-Z (pi)", float64, nullable=True),
# Column("CH-Z (pi)", float64, nullable=True),
# Column("CH% (pi)", float64, nullable=True),
# Column("wCT", float64, nullable=True),
# Column("BB/K", float64, nullable=True),
# Column("FT% (pfx)", float64, nullable=True),
# Column("KN% (pi)", float64, nullable=True),
# Column("wKN/C", float64, nullable=True),
# Column("BUH%", float64, nullable=True),
# Column("wCB", float64, nullable=True),
# Column("wFC/C (pfx)", float64, nullable=True),
# Column("Z-Contact% (pfx)", float64, nullable=True),
# Column("CHv", float64, nullable=True),
# Column("CH-X (pfx)", float64, nullable=True),
# Column("KNv", float64, nullable=True),
# Column("wCH", float64, nullable=True),
# Column("wCB/C", float64, nullable=True),
# Column("Spd", float64, nullable=True),
# Column("SL-X (pi)", float64, nullable=True),
# Column("vCS (pi)", float64, nullable=True),
# Column("FB%", float64, nullable=True),
# Column("CB%", float64, nullable=True),
# Column("HR", float64, nullable=True),
# Column("Rep", float64, nullable=True),
# Column("wFB/C", float64, nullable=True),
# Column("KC% (pfx)", float64, nullable=True),
# Column("EP-Z (pfx)", float64, nullable=True),
# Column("FC% (pi)", float64, nullable=True),
# Column("FS-Z (pfx)", float64, nullable=True),
# Column("3B", float64, nullable=True),
# Column("wSC/C (pfx)", float64, nullable=True),
# Column("IFH", float64, nullable=True),
# Column("EP-X (pfx)", float64, nullable=True),
# Column("EP% (pfx)", float64, nullable=True),
# Column("wCH/C", float64, nullable=True),
# Column("wFC (pi)", float64, nullable=True),
# Column("wKN (pfx)", float64, nullable=True),
# Column("G", float64, nullable=True),
# Column("CU-X (pi)", float64, nullable=True),
# Column("Soft%", float64, nullable=True),
# Column("Season", float64, nullable=True),
# Column("wEP/C (pfx)", float64, nullable=True),
# Column("vSL (pi)", float64, nullable=True),
# Column("BABIP", float64, nullable=True),
# Column("SwStr%", float64, nullable=True),
# Column("wRC+", float64, nullable=True),
# Column("FS% (pfx)", float64, nullable=True),
# Column("BUH", float64, nullable=True),
# Column("PA", float64, nullable=True),
# Column("vCU (pi)", float64, nullable=True),
# Column("wSB/C (pi)", float64, nullable=True),
# Column("HR/FB", float64, nullable=True),
# Column("SI-Z (pi)", float64, nullable=True),
# Column("PH", float64, nullable=True),
# Column("wXX (pi)", float64, nullable=True),
# Column("SC-X (pfx)", float64, nullable=True),
# Column("wCS (pi)", float64, nullable=True),
# Column("Age Rng", object, nullable=True),
# Column("SL% (pi)", float64, nullable=True),
# Column("CS-X (pi)", float64, nullable=True),
# Column("wSI/C (pfx)", float64, nullable=True),
# Column("wCU (pi)", float64, nullable=True),
# Column("wFS/C (pfx)", float64, nullable=True),
# Column("LD%", float64, nullable=True),
# Column("Clutch", float64, nullable=True),
# Column("Age", float64, nullable=True),
# Column("FS-Z (pi)", float64, nullable=True),
# Column("wSF/C", float64, nullable=True),
# Column("wFS/C (pi)", float64, nullable=True),
# Column("Pace", float64, nullable=True),
# Column("wSB", float64, nullable=True),
# Column("CBv", float64, nullable=True),
# Column("Swing%", float64, nullable=True),
# Column("wCU/C (pi)", float64, nullable=True),
# Column("Team", object, nullable=True),
# Column("O-Swing% (pfx)", float64, nullable=True),
# Column("wSL (pi)", float64, nullable=True),
# Column("KN-X (pfx)", float64, nullable=True),
# Column("FO-Z (pfx)", float64, nullable=True),
# Column("SI-Z (pfx)", float64, nullable=True),
# Column("phLI", float64, nullable=True),
# Column("GB%", float64, nullable=True),
# Column("wRC", float64, nullable=True),
# Column("OPS", float64, nullable=True),
# Column("WAR", float64, nullable=True),
# Column("vKN (pfx)", float64, nullable=True),
# Column("TTO%", float64, nullable=True),
# Column("vKN (pi)", float64, nullable=True),
# Column("wKN/C (pfx)", float64, nullable=True),
# Column("CH% (pfx)", float64, nullable=True),
# Column("vSL (pfx)", float64, nullable=True),
# Column("wGDP", float64, nullable=True),
# Column("FA-Z (pfx)", float64, nullable=True),
# Column("Pull%", float64, nullable=True),
# Column("Z-Swing% (pfx)", float64, nullable=True),
# Column("FA% (pfx)", float64, nullable=True),
# Column("IFFB%", float64, nullable=True),
# Column("wFS (pfx)", float64, nullable=True),
# Column("FA% (pi)", float64, nullable=True),
# Column("wKN (pi)", float64, nullable=True),
# Column("SC% (pfx)", float64, nullable=True),
# Column("FS-X (pi)", float64, nullable=True),
# Column("SI-X (pfx)", float64, nullable=True),
# Column("wSI/C (pi)", float64, nullable=True),
# Column("XX%", float64, nullable=True),
# Column("K%", float64, nullable=True),
# Column("wCS/C (pi)", float64, nullable=True),
# Column("F-Strike%", float64, nullable=True),
# Column("REW", float64, nullable=True),
# Column("vFO (pfx)", float64, nullable=True),
# Column("FB", float64, nullable=True),
# Column("1B", float64, nullable=True),
# Column("ISO", float64, nullable=True),
# Column("WPA/LI", float64, nullable=True),
# Column("SL-Z (pi)", float64, nullable=True),
# Column("FC-X (pi)", float64, nullable=True),
# Column("wSI (pi)", float64, nullable=True),
# Column("CU-Z (pfx)", float64, nullable=True),
# Column("XX-X (pi)", float64, nullable=True),
# Column("Contact% (pfx)", float64, nullable=True),
# Column("CTv", float64, nullable=True),
# Column("PO%", float64, nullable=True),
# Column("wOBA", float64, nullable=True),
# Column("wFB", float64, nullable=True),
# Column("CH-X (pi)", float64, nullable=True),
# Column("BB%", float64, nullable=True),
# Column("Pitches", float64, nullable=True),
# Column("vXX (pi)", float64, nullable=True),
# Column("RE24", float64, nullable=True),
# Column("wKN/C (pi)", float64, nullable=True),
# Column("wSL/C (pi)", float64, nullable=True),
# Column("SC-Z (pfx)", float64, nullable=True),
# Column("FB% (Pitch)", float64, nullable=True),
# Column("KN-X (pi)", float64, nullable=True),
# Column("WPA", float64, nullable=True),
# Column("CU-X (pfx)", float64, nullable=True),
# Column("wFS (pi)", float64, nullable=True),
# Column("FA-X (pfx)", float64, nullable=True),
# Column("Balls", float64, nullable=True),
# Column("Swing% (pi)", float64, nullable=True),
# Column("FBv", float64, nullable=True),
# Column("KC-Z (pfx)", float64, nullable=True),
# Column("Z-Swing% (pi)", float64, nullable=True),
# Column("XX% (pi)", float64, nullable=True),
# Column("wFA (pfx)", float64, nullable=True),
# Column("wCT/C", float64, nullable=True),
# Column("R", float64, nullable=True),
# Column("CS", float64, nullable=True),
# Column("O-Swing%", float64, nullable=True),
# Column("Fld", float64, nullable=True),
# Column("OBP", float64, nullable=True),
# Column("wXX/C (pi)", float64, nullable=True),
# Column("GDP", float64, nullable=True),
# Column("-WPA", float64, nullable=True),
# Column("wFA (pi)", float64, nullable=True),
# Column("FC-X (pfx)", float64, nullable=True),
# Column("wFO/C (pfx)", float64, nullable=True),
# Column("CT%", float64, nullable=True),
# Column("vFC (pi)", float64, nullable=True),
# Column("SH", float64, nullable=True),
# Column("SO", float64, nullable=True),
# Column("Cent%", float64, nullable=True),
# Column("wEP (pfx)", float64, nullable=True),
# Column("wSL/C", float64, nullable=True),
# Column("O-Swing% (pi)", float64, nullable=True),
# Column("SB", float64, nullable=True),
# Column("CS-Z (pi)", float64, nullable=True),
# Column("SL% (pfx)", float64, nullable=True),
# Column("SF", float64, nullable=True),
# Column("O-Contact% (pi)", float64, nullable=True),
# Column("Zone% (pi)", float64, nullable=True),
# Column("Lg", float64, nullable=True),
# Column("vSB (pi)", float64, nullable=True),
# Column("IBB", float64, nullable=True),
# Column("BsR", float64, nullable=True),
# Column("SI% (pi)", float64, nullable=True),
# Column("vFS (pfx)", float64, nullable=True),
# Column("FO-X (pfx)", float64, nullable=True),
# Column("XX-Z (pi)", float64, nullable=True),
# Column("FT-X (pfx)", float64, nullable=True),
# Column("wSB (pi)", float64, nullable=True),
# Column("vKC (pfx)", float64, nullable=True),
# Column("FC% (pfx)", float64, nullable=True),
# Column("LD", float64, nullable=True),
# Column("UBR", float64, nullable=True),
# Column("wFT/C (pfx)", float64, nullable=True),
# Column("Zone% (pfx)", float64, nullable=True),
# Column("wSL/C (pfx)", float64, nullable=True),
# Column("wKC/C (pfx)", float64, nullable=True),
# Column("IFFB", float64, nullable=True),
# Column("Z-Contact% (pi)", float64, nullable=True),
# Column("SL%", float64, nullable=True),
# Column("CU% (pfx)", float64, nullable=True),
# Column("IFH%", float64, nullable=True),
# Column("O-Contact% (pfx)", float64, nullable=True),
# Column("vCU (pfx)", float64, nullable=True),
# Column("wCU/C (pfx)", float64, nullable=True),
# Column("AB", float64, nullable=True),
# Column("Off", float64, nullable=True),
# Column("Name", object, nullable=True),
# Column("Dol", object, nullable=True),
# Column("Pace (pi)", float64, nullable=True),
# Column("vFS (pi)", float64, nullable=True),
# Column("wSC (pfx)", float64, nullable=True),
# Column("Z-Swing%", float64, nullable=True),
# Column("O-Contact%", float64, nullable=True),
# Column("CH-Z (pfx)", float64, nullable=True),
# Column("RBI", float64, nullable=True),
# Column("SB-X (pi)", float64, nullable=True),
# Column("FT-Z (pfx)", float64, nullable=True),
# Column("SLG", float64, nullable=True),
# Column("vSI (pfx)", float64, nullable=True),
# Column("Z-Contact%", float64, nullable=True),
# Column("CU% (pi)", float64, nullable=True),
# Column("AVG", float64, nullable=True),
# Column("Contact%", float64, nullable=True),
# Column("wRAA", float64, nullable=True),
# Column("SLv", float64, nullable=True),
# Column("SI% (pfx)", float64, nullable=True),
# Column("Pos", float64, nullable=True),
# Column("vCH (pi)", float64, nullable=True),
# Column("wFO (pfx)", float64, nullable=True),
# Column("+WPA", float64, nullable=True),
# Column("vCH (pfx)", float64, nullable=True),
# Column("KN-Z (pi)", float64, nullable=True),
# Column("Contact% (pi)", float64, nullable=True),
# Column("KN-Z (pfx)", float64, nullable=True),

# %%
pitching = pitching_stats(2017, 2017)

# %%
pitching.head()
# Out:
#      Season               Name       Team   Age     W    L   ERA  WAR     G  \
# 120  2017.0         Chris Sale    Red Sox  28.0  17.0  8.0  2.90  7.7  32.0
# 53   2017.0       Corey Kluber    Indians  31.0  18.0  4.0  2.25  7.3  29.0
# 69   2017.0       Max Scherzer  Nationals  32.0  16.0  6.0  2.51  6.0  31.0
# 131  2017.0      Luis Severino    Yankees  23.0  14.0  6.0  2.98  5.7  31.0
# 71   2017.0  Stephen Strasburg  Nationals  28.0  15.0  4.0  2.52  5.6  28.0
#
#        GS    ...      wSL/C (pi)  wXX/C (pi)  O-Swing% (pi)  Z-Swing% (pi)  \
# 120  32.0    ...            0.68         NaN          0.375          0.617
# 53   29.0    ...            4.65        9.31          0.388          0.594
# 69   31.0    ...            3.47        4.08          0.368          0.651
# 131  31.0    ...            1.66       -9.57          0.336          0.644
# 71   28.0    ...            1.32         NaN          0.364          0.613
#
#      Swing% (pi)  O-Contact% (pi)  Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  \
# 120        0.499            0.542            0.797          0.704       0.514
# 53         0.489            0.432            0.852          0.681       0.488
# 69         0.512            0.497            0.807          0.697       0.507
# 131        0.490            0.559            0.827          0.735       0.500
# 71         0.490            0.528            0.850          0.732       0.506
#
#      Pace (pi)
# 120       20.9
# 53        23.5
# 69        25.1
# 131       22.2
# 71        25.2
#
# [5 rows x 299 columns]

# %%
pitching.dtypes
# Out:
# Season             float64
# Name                object
# Team                object
# Age                float64
# W                  float64
# L                  float64
# ERA                float64
# WAR                float64
# G                  float64
# GS                 float64
# CG                 float64
# ShO                float64
# SV                 float64
# BS                 float64
# IP                 float64
# TBF                float64
# H                  float64
# R                  float64
# ER                 float64
# HR                 float64
# BB                 float64
# IBB                float64
# HBP                float64
# WP                 float64
# BK                 float64
# SO                 float64
# GB                 float64
# FB                 float64
# LD                 float64
# IFFB               float64
#                     ...
# wCH (pi)           float64
# wCS (pi)           float64
# wCU (pi)           float64
# wFA (pi)           float64
# wFC (pi)           float64
# wFS (pi)           float64
# wKN (pi)           float64
# wSB (pi)           float64
# wSI (pi)           float64
# wSL (pi)           float64
# wXX (pi)           float64
# wCH/C (pi)         float64
# wCS/C (pi)         float64
# wCU/C (pi)         float64
# wFA/C (pi)         float64
# wFC/C (pi)         float64
# wFS/C (pi)         float64
# wKN/C (pi)         float64
# wSB/C (pi)         float64
# wSI/C (pi)         float64
# wSL/C (pi)         float64
# wXX/C (pi)         float64
# O-Swing% (pi)      float64
# Z-Swing% (pi)      float64
# Swing% (pi)        float64
# O-Contact% (pi)    float64
# Z-Contact% (pi)    float64
# Contact% (pi)      float64
# Zone% (pi)         float64
# Pace (pi)          float64
# Length: 299, dtype: object

# %%
for key, value in pitching.dtypes.to_dict().iteritems():
    print str('Column("' + str(key) + '", ' + str(value) + ', nullable=True),')
# Out:
# Column("UN% (pfx)", float64, nullable=True),
# Column("wCH (pi)", float64, nullable=True),
# Column("KC-X (pfx)", float64, nullable=True),
# Column("FC-Z (pfx)", float64, nullable=True),
# Column("BB", float64, nullable=True),
# Column("wKN", float64, nullable=True),
# Column("wCH/C (pfx)", float64, nullable=True),
# Column("wKC (pfx)", float64, nullable=True),
# Column("BK", float64, nullable=True),
# Column("wCH/C (pi)", float64, nullable=True),
# Column("BU", float64, nullable=True),
# Column("FC-Z (pi)", float64, nullable=True),
# Column("BB/9", float64, nullable=True),
# Column("Oppo%", float64, nullable=True),
# Column("vSC (pfx)", float64, nullable=True),
# Column("WP", float64, nullable=True),
# Column("wSL (pfx)", float64, nullable=True),
# Column("wCU (pfx)", float64, nullable=True),
# Column("SF%", float64, nullable=True),
# Column("HBP", float64, nullable=True),
# Column("pLI", float64, nullable=True),
# Column("FA-X (pi)", float64, nullable=True),
# Column("vSI (pi)", float64, nullable=True),
# Column("E-F", float64, nullable=True),
# Column("FS% (pi)", float64, nullable=True),
# Column("CH%", float64, nullable=True),
# Column("Zone%", float64, nullable=True),
# Column("RS", float64, nullable=True),
# Column("SL-Z (pfx)", float64, nullable=True),
# Column("wFC/C (pi)", float64, nullable=True),
# Column("KN%", float64, nullable=True),
# Column("wFC (pfx)", float64, nullable=True),
# Column("wSL", float64, nullable=True),
# Column("Strikes", float64, nullable=True),
# Column("GB/FB", float64, nullable=True),
# Column("RAR", float64, nullable=True),
# Column("wSI (pfx)", float64, nullable=True),
# Column("FS-X (pfx)", float64, nullable=True),
# Column("SI-X (pi)", float64, nullable=True),
# Column("SL-X (pfx)", float64, nullable=True),
# Column("SB-Z (pi)", float64, nullable=True),
# Column("vFA (pi)", float64, nullable=True),
# Column("vFC (pfx)", float64, nullable=True),
# Column("FIP", float64, nullable=True),
# Column("GS", float64, nullable=True),
# Column("CS% (pi)", float64, nullable=True),
# Column("Relief-IP", float64, nullable=True),
# Column("Med%", float64, nullable=True),
# Column("SFv", float64, nullable=True),
# Column("H", float64, nullable=True),
# Column("SB% (pi)", float64, nullable=True),
# Column("L", float64, nullable=True),
# Column("KN% (pfx)", float64, nullable=True),
# Column("wFA/C (pfx)", float64, nullable=True),
# Column("FO% (pfx)", float64, nullable=True),
# Column("GB", float64, nullable=True),
# Column("Swing% (pfx)", float64, nullable=True),
# Column("vEP (pfx)", float64, nullable=True),
# Column("wCH (pfx)", float64, nullable=True),
# Column("wKN/C (pfx)", float64, nullable=True),
# Column("vFT (pfx)", float64, nullable=True),
# Column("FA-Z (pi)", float64, nullable=True),
# Column("SC% (pfx)", float64, nullable=True),
# Column("CH-Z (pi)", float64, nullable=True),
# Column("CH% (pi)", float64, nullable=True),
# Column("wCT", float64, nullable=True),
# Column("FDP-Wins", float64, nullable=True),
# Column("FT% (pfx)", float64, nullable=True),
# Column("KN% (pi)", float64, nullable=True),
# Column("ERA-", float64, nullable=True),
# Column("wKN/C", float64, nullable=True),
# Column("BUH%", float64, nullable=True),
# Column("wCB", float64, nullable=True),
# Column("wFC/C (pfx)", float64, nullable=True),
# Column("Z-Contact% (pfx)", float64, nullable=True),
# Column("CHv", float64, nullable=True),
# Column("CH-X (pfx)", float64, nullable=True),
# Column("KNv", float64, nullable=True),
# Column("wCH", float64, nullable=True),
# Column("wCB/C", float64, nullable=True),
# Column("SL-X (pi)", float64, nullable=True),
# Column("ShO", float64, nullable=True),
# Column("vCS (pi)", float64, nullable=True),
# Column("SIERA", float64, nullable=True),
# Column("Pace (pi)", float64, nullable=True),
# Column("FB%", float64, nullable=True),
# Column("CB%", float64, nullable=True),
# Column("HR", float64, nullable=True),
# Column("FA% (pi)", float64, nullable=True),
# Column("BS", float64, nullable=True),
# Column("wFB/C", float64, nullable=True),
# Column("KC% (pfx)", float64, nullable=True),
# Column("tERA", float64, nullable=True),
# Column("EP-Z (pfx)", float64, nullable=True),
# Column("K/9", float64, nullable=True),
# Column("FC% (pi)", float64, nullable=True),
# Column("FS-Z (pfx)", float64, nullable=True),
# Column("wSC/C (pfx)", float64, nullable=True),
# Column("IFH", float64, nullable=True),
# Column("EP-X (pfx)", float64, nullable=True),
# Column("EP% (pfx)", float64, nullable=True),
# Column("H/9", float64, nullable=True),
# Column("wFC (pi)", float64, nullable=True),
# Column("wKN (pfx)", float64, nullable=True),
# Column("G", float64, nullable=True),
# Column("CU-X (pi)", float64, nullable=True),
# Column("Soft%", float64, nullable=True),
# Column("Season", float64, nullable=True),
# Column("wEP/C (pfx)", float64, nullable=True),
# Column("vSL (pi)", float64, nullable=True),
# Column("Hard%", float64, nullable=True),
# Column("SwStr%", float64, nullable=True),
# Column("FS% (pfx)", float64, nullable=True),
# Column("kwERA", float64, nullable=True),
# Column("BUH", float64, nullable=True),
# Column("wFT (pfx)", float64, nullable=True),
# Column("vCU (pi)", float64, nullable=True),
# Column("wSB/C (pi)", float64, nullable=True),
# Column("LOB-Wins", float64, nullable=True),
# Column("HR/FB", float64, nullable=True),
# Column("SI-Z (pi)", float64, nullable=True),
# Column("wXX (pi)", float64, nullable=True),
# Column("SC-X (pfx)", float64, nullable=True),
# Column("Age", float64, nullable=True),
# Column("wCS (pi)", float64, nullable=True),
# Column("Age Rng", object, nullable=True),
# Column("SL% (pi)", float64, nullable=True),
# Column("CS-X (pi)", float64, nullable=True),
# Column("wSI/C (pfx)", float64, nullable=True),
# Column("wCU (pi)", float64, nullable=True),
# Column("wFS/C (pfx)", float64, nullable=True),
# Column("wEP (pfx)", float64, nullable=True),
# Column("LD%", float64, nullable=True),
# Column("Clutch", float64, nullable=True),
# Column("Dollars", object, nullable=True),
# Column("wSF/C", float64, nullable=True),
# Column("wFS/C (pi)", float64, nullable=True),
# Column("RS/9", float64, nullable=True),
# Column("vFA (pfx)", float64, nullable=True),
# Column("CBv", float64, nullable=True),
# Column("Swing%", float64, nullable=True),
# Column("W", float64, nullable=True),
# Column("Team", object, nullable=True),
# Column("O-Swing% (pfx)", float64, nullable=True),
# Column("wSL (pi)", float64, nullable=True),
# Column("xFIP", float64, nullable=True),
# Column("FO-Z (pfx)", float64, nullable=True),
# Column("ER", float64, nullable=True),
# Column("SI-Z (pfx)", float64, nullable=True),
# Column("MD", float64, nullable=True),
# Column("GB%", float64, nullable=True),
# Column("FC-X (pfx)", float64, nullable=True),
# Column("Z-Swing% (pi)", float64, nullable=True),
# Column("wSF", float64, nullable=True),
# Column("vKN (pi)", float64, nullable=True),
# Column("HR/9", float64, nullable=True),
# Column("CH% (pfx)", float64, nullable=True),
# Column("vSL (pfx)", float64, nullable=True),
# Column("wSB (pi)", float64, nullable=True),
# Column("FA-Z (pfx)", float64, nullable=True),
# Column("Pull%", float64, nullable=True),
# Column("Z-Swing% (pfx)", float64, nullable=True),
# Column("FA% (pfx)", float64, nullable=True),
# Column("AVG", float64, nullable=True),
# Column("wFS (pfx)", float64, nullable=True),
# Column("FIP-", float64, nullable=True),
# Column("K/BB", float64, nullable=True),
# Column("TBF", float64, nullable=True),
# Column("SI-X (pfx)", float64, nullable=True),
# Column("wSI/C (pi)", float64, nullable=True),
# Column("XX%", float64, nullable=True),
# Column("K%", float64, nullable=True),
# Column("F-Strike%", float64, nullable=True),
# Column("REW", float64, nullable=True),
# Column("vFO (pfx)", float64, nullable=True),
# Column("FB", float64, nullable=True),
# Column("WPA/LI", float64, nullable=True),
# Column("SL-Z (pi)", float64, nullable=True),
# Column("FC-X (pi)", float64, nullable=True),
# Column("wSI (pi)", float64, nullable=True),
# Column("CU-Z (pfx)", float64, nullable=True),
# Column("XX-X (pi)", float64, nullable=True),
# Column("Contact% (pfx)", float64, nullable=True),
# Column("CTv", float64, nullable=True),
# Column("FS-Z (pi)", float64, nullable=True),
# Column("BABIP", float64, nullable=True),
# Column("wFB", float64, nullable=True),
# Column("CH-X (pi)", float64, nullable=True),
# Column("wCH/C", float64, nullable=True),
# Column("Pitches", float64, nullable=True),
# Column("KN-X (pfx)", float64, nullable=True),
# Column("RE24", float64, nullable=True),
# Column("wKN/C (pi)", float64, nullable=True),
# Column("wSL/C (pi)", float64, nullable=True),
# Column("SC-Z (pfx)", float64, nullable=True),
# Column("vXX (pi)", float64, nullable=True),
# Column("Pace", float64, nullable=True),
# Column("KN-X (pi)", float64, nullable=True),
# Column("WPA", float64, nullable=True),
# Column("CU-X (pfx)", float64, nullable=True),
# Column("wFS (pi)", float64, nullable=True),
# Column("gmLI", float64, nullable=True),
# Column("Balls", float64, nullable=True),
# Column("Swing% (pi)", float64, nullable=True),
# Column("FBv", float64, nullable=True),
# Column("KC-Z (pfx)", float64, nullable=True),
# Column("CG", float64, nullable=True),
# Column("XX% (pi)", float64, nullable=True),
# Column("wFA (pfx)", float64, nullable=True),
# Column("wCT/C", float64, nullable=True),
# Column("R", float64, nullable=True),
# Column("wCU/C (pi)", float64, nullable=True),
# Column("O-Swing%", float64, nullable=True),
# Column("Starting", float64, nullable=True),
# Column("WAR", float64, nullable=True),
# Column("WHIP", float64, nullable=True),
# Column("wXX/C (pi)", float64, nullable=True),
# Column("CU-Z (pi)", float64, nullable=True),
# Column("wKN (pi)", float64, nullable=True),
# Column("BIP-Wins", float64, nullable=True),
# Column("-WPA", float64, nullable=True),
# Column("LOB%", float64, nullable=True),
# Column("wFA (pi)", float64, nullable=True),
# Column("SV", float64, nullable=True),
# Column("wFO/C (pfx)", float64, nullable=True),
# Column("CT%", float64, nullable=True),
# Column("vFC (pi)", float64, nullable=True),
# Column("IFFB%", float64, nullable=True),
# Column("SO", float64, nullable=True),
# Column("Cent%", float64, nullable=True),
# Column("Start-IP", float64, nullable=True),
# Column("FS-X (pi)", float64, nullable=True),
# Column("O-Swing% (pi)", float64, nullable=True),
# Column("XX-Z (pi)", float64, nullable=True),
# Column("CS-Z (pi)", float64, nullable=True),
# Column("SL% (pfx)", float64, nullable=True),
# Column("O-Contact% (pi)", float64, nullable=True),
# Column("SD", float64, nullable=True),
# Column("wCS/C (pi)", float64, nullable=True),
# Column("vKN (pfx)", float64, nullable=True),
# Column("Relieving", float64, nullable=True),
# Column("FA-X (pfx)", float64, nullable=True),
# Column("IBB", float64, nullable=True),
# Column("Zone% (pi)", float64, nullable=True),
# Column("vFS (pfx)", float64, nullable=True),
# Column("FO-X (pfx)", float64, nullable=True),
# Column("inLI", float64, nullable=True),
# Column("ERA", float64, nullable=True),
# Column("FT-X (pfx)", float64, nullable=True),
# Column("vKC (pfx)", float64, nullable=True),
# Column("FC% (pfx)", float64, nullable=True),
# Column("K-BB%", float64, nullable=True),
# Column("LD", float64, nullable=True),
# Column("wFA/C (pi)", float64, nullable=True),
# Column("xFIP-", float64, nullable=True),
# Column("BB%", float64, nullable=True),
# Column("wFT/C (pfx)", float64, nullable=True),
# Column("Zone% (pfx)", float64, nullable=True),
# Column("wSL/C (pfx)", float64, nullable=True),
# Column("wKC/C (pfx)", float64, nullable=True),
# Column("IFFB", float64, nullable=True),
# Column("Z-Contact% (pi)", float64, nullable=True),
# Column("SL%", float64, nullable=True),
# Column("CU% (pfx)", float64, nullable=True),
# Column("IFH%", float64, nullable=True),
# Column("O-Contact% (pfx)", float64, nullable=True),
# Column("vCU (pfx)", float64, nullable=True),
# Column("wCU/C (pfx)", float64, nullable=True),
# Column("TTO%", float64, nullable=True),
# Column("Name", object, nullable=True),
# Column("vSB (pi)", float64, nullable=True),
# Column("IP", float64, nullable=True),
# Column("RA9-WAR", float64, nullable=True),
# Column("vFS (pi)", float64, nullable=True),
# Column("wSC (pfx)", float64, nullable=True),
# Column("Z-Swing%", float64, nullable=True),
# Column("O-Contact%", float64, nullable=True),
# Column("CH-Z (pfx)", float64, nullable=True),
# Column("exLI", float64, nullable=True),
# Column("SB-X (pi)", float64, nullable=True),
# Column("FT-Z (pfx)", float64, nullable=True),
# Column("PO%", float64, nullable=True),
# Column("vSI (pfx)", float64, nullable=True),
# Column("Z-Contact%", float64, nullable=True),
# Column("CU% (pi)", float64, nullable=True),
# Column("HLD", float64, nullable=True),
# Column("Contact%", float64, nullable=True),
# Column("wSL/C", float64, nullable=True),
# Column("SLv", float64, nullable=True),
# Column("SI% (pfx)", float64, nullable=True),
# Column("SI% (pi)", float64, nullable=True),
# Column("vCH (pi)", float64, nullable=True),
# Column("wFO (pfx)", float64, nullable=True),
# Column("+WPA", float64, nullable=True),
# Column("vCH (pfx)", float64, nullable=True),
# Column("KN-Z (pi)", float64, nullable=True),
# Column("Pulls", float64, nullable=True),
# Column("Contact% (pi)", float64, nullable=True),
# Column("KN-Z (pfx)", float64, nullable=True),

# %%
for key, value in pitching.dtypes.to_dict().iteritems():
    print str(str(key) + " - " + str(value))
# Out:
# UN% (pfx) - float64
# wCH (pi) - float64
# KC-X (pfx) - float64
# FC-Z (pfx) - float64
# BB - float64
# wKN - float64
# wCH/C (pfx) - float64
# wKC (pfx) - float64
# BK - float64
# wCH/C (pi) - float64
# BU - float64
# FC-Z (pi) - float64
# BB/9 - float64
# Oppo% - float64
# vSC (pfx) - float64
# WP - float64
# wSL (pfx) - float64
# wCU (pfx) - float64
# SF% - float64
# HBP - float64
# pLI - float64
# FA-X (pi) - float64
# vSI (pi) - float64
# E-F - float64
# FS% (pi) - float64
# CH% - float64
# Zone% - float64
# RS - float64
# SL-Z (pfx) - float64
# wFC/C (pi) - float64
# KN% - float64
# wFC (pfx) - float64
# wSL - float64
# Strikes - float64
# GB/FB - float64
# RAR - float64
# wSI (pfx) - float64
# FS-X (pfx) - float64
# SI-X (pi) - float64
# SL-X (pfx) - float64
# SB-Z (pi) - float64
# vFA (pi) - float64
# vFC (pfx) - float64
# FIP - float64
# GS - float64
# CS% (pi) - float64
# Relief-IP - float64
# Med% - float64
# SFv - float64
# H - float64
# SB% (pi) - float64
# L - float64
# KN% (pfx) - float64
# wFA/C (pfx) - float64
# FO% (pfx) - float64
# GB - float64
# Swing% (pfx) - float64
# vEP (pfx) - float64
# wCH (pfx) - float64
# wKN/C (pfx) - float64
# vFT (pfx) - float64
# FA-Z (pi) - float64
# SC% (pfx) - float64
# CH-Z (pi) - float64
# CH% (pi) - float64
# wCT - float64
# FDP-Wins - float64
# FT% (pfx) - float64
# KN% (pi) - float64
# ERA- - float64
# wKN/C - float64
# BUH% - float64
# wCB - float64
# wFC/C (pfx) - float64
# Z-Contact% (pfx) - float64
# CHv - float64
# CH-X (pfx) - float64
# KNv - float64
# wCH - float64
# wCB/C - float64
# SL-X (pi) - float64
# ShO - float64
# vCS (pi) - float64
# SIERA - float64
# Pace (pi) - float64
# FB% - float64
# CB% - float64
# HR - float64
# FA% (pi) - float64
# BS - float64
# wFB/C - float64
# KC% (pfx) - float64
# tERA - float64
# EP-Z (pfx) - float64
# K/9 - float64
# FC% (pi) - float64
# FS-Z (pfx) - float64
# wSC/C (pfx) - float64
# IFH - float64
# EP-X (pfx) - float64
# EP% (pfx) - float64
# H/9 - float64
# wFC (pi) - float64
# wKN (pfx) - float64
# G - float64
# CU-X (pi) - float64
# Soft% - float64
# Season - float64
# wEP/C (pfx) - float64
# vSL (pi) - float64
# Hard% - float64
# SwStr% - float64
# FS% (pfx) - float64
# kwERA - float64
# BUH - float64
# wFT (pfx) - float64
# vCU (pi) - float64
# wSB/C (pi) - float64
# LOB-Wins - float64
# HR/FB - float64
# SI-Z (pi) - float64
# wXX (pi) - float64
# SC-X (pfx) - float64
# Age - float64
# wCS (pi) - float64
# Age Rng - object
# SL% (pi) - float64
# CS-X (pi) - float64
# wSI/C (pfx) - float64
# wCU (pi) - float64
# wFS/C (pfx) - float64
# wEP (pfx) - float64
# LD% - float64
# Clutch - float64
# Dollars - object
# wSF/C - float64
# wFS/C (pi) - float64
# RS/9 - float64
# vFA (pfx) - float64
# CBv - float64
# Swing% - float64
# W - float64
# Team - object
# O-Swing% (pfx) - float64
# wSL (pi) - float64
# xFIP - float64
# FO-Z (pfx) - float64
# ER - float64
# SI-Z (pfx) - float64
# MD - float64
# GB% - float64
# FC-X (pfx) - float64
# Z-Swing% (pi) - float64
# wSF - float64
# vKN (pi) - float64
# HR/9 - float64
# CH% (pfx) - float64
# vSL (pfx) - float64
# wSB (pi) - float64
# FA-Z (pfx) - float64
# Pull% - float64
# Z-Swing% (pfx) - float64
# FA% (pfx) - float64
# AVG - float64
# wFS (pfx) - float64
# FIP- - float64
# K/BB - float64
# TBF - float64
# SI-X (pfx) - float64
# wSI/C (pi) - float64
# XX% - float64
# K% - float64
# F-Strike% - float64
# REW - float64
# vFO (pfx) - float64
# FB - float64
# WPA/LI - float64
# SL-Z (pi) - float64
# FC-X (pi) - float64
# wSI (pi) - float64
# CU-Z (pfx) - float64
# XX-X (pi) - float64
# Contact% (pfx) - float64
# CTv - float64
# FS-Z (pi) - float64
# BABIP - float64
# wFB - float64
# CH-X (pi) - float64
# wCH/C - float64
# Pitches - float64
# KN-X (pfx) - float64
# RE24 - float64
# wKN/C (pi) - float64
# wSL/C (pi) - float64
# SC-Z (pfx) - float64
# vXX (pi) - float64
# Pace - float64
# KN-X (pi) - float64
# WPA - float64
# CU-X (pfx) - float64
# wFS (pi) - float64
# gmLI - float64
# Balls - float64
# Swing% (pi) - float64
# FBv - float64
# KC-Z (pfx) - float64
# CG - float64
# XX% (pi) - float64
# wFA (pfx) - float64
# wCT/C - float64
# R - float64
# wCU/C (pi) - float64
# O-Swing% - float64
# Starting - float64
# WAR - float64
# WHIP - float64
# wXX/C (pi) - float64
# CU-Z (pi) - float64
# wKN (pi) - float64
# BIP-Wins - float64
# -WPA - float64
# LOB% - float64
# wFA (pi) - float64
# SV - float64
# wFO/C (pfx) - float64
# CT% - float64
# vFC (pi) - float64
# IFFB% - float64
# SO - float64
# Cent% - float64
# Start-IP - float64
# FS-X (pi) - float64
# O-Swing% (pi) - float64
# XX-Z (pi) - float64
# CS-Z (pi) - float64
# SL% (pfx) - float64
# O-Contact% (pi) - float64
# SD - float64
# wCS/C (pi) - float64
# vKN (pfx) - float64
# Relieving - float64
# FA-X (pfx) - float64
# IBB - float64
# Zone% (pi) - float64
# vFS (pfx) - float64
# FO-X (pfx) - float64
# inLI - float64
# ERA - float64
# FT-X (pfx) - float64
# vKC (pfx) - float64
# FC% (pfx) - float64
# K-BB% - float64
# LD - float64
# wFA/C (pi) - float64
# xFIP- - float64
# BB% - float64
# wFT/C (pfx) - float64
# Zone% (pfx) - float64
# wSL/C (pfx) - float64
# wKC/C (pfx) - float64
# IFFB - float64
# Z-Contact% (pi) - float64
# SL% - float64
# CU% (pfx) - float64
# IFH% - float64
# O-Contact% (pfx) - float64
# vCU (pfx) - float64
# wCU/C (pfx) - float64
# TTO% - float64
# Name - object
# vSB (pi) - float64
# IP - float64
# RA9-WAR - float64
# vFS (pi) - float64
# wSC (pfx) - float64
# Z-Swing% - float64
# O-Contact% - float64
# CH-Z (pfx) - float64
# exLI - float64
# SB-X (pi) - float64
# FT-Z (pfx) - float64
# PO% - float64
# vSI (pfx) - float64
# Z-Contact% - float64
# CU% (pi) - float64
# HLD - float64
# Contact% - float64
# wSL/C - float64
# SLv - float64
# SI% (pfx) - float64
# SI% (pi) - float64
# vCH (pi) - float64
# wFO (pfx) - float64
# +WPA - float64
# vCH (pfx) - float64
# KN-Z (pi) - float64
# Pulls - float64
# Contact% (pi) - float64
# KN-Z (pfx) - float64

# %%
data = statcast(start_dt='2017-04-22', end_dt='2017-04-22')

# %%
data
# Out:
#       index pitch_type  game_date  release_speed  release_pos_x  \
# 0       246         SI 2017-04-22           96.8        -3.3744
# 1       255         SL 2017-04-22           92.6        -3.5496
# 2       264         SL 2017-04-22           92.5        -3.5965
# 3       273         SI 2017-04-22           96.5        -3.2875
# 4       282         FF 2017-04-22           98.7         0.3794
# 5       293         FF 2017-04-22           98.3         0.6378
# 6       300         SL 2017-04-22           86.9         1.1154
# 7       311         FF 2017-04-22           98.6         0.5900
# 8       322         FF 2017-04-22           97.4         0.5625
# 9       333         FF 2017-04-22           96.7         0.8350
# 10      344         CU 2017-04-22           70.8         2.6331
# 11      355         CU 2017-04-22           70.8         2.7472
# 12      368         CU 2017-04-22           71.0         2.5724
# 13      377         SI 2017-04-22           89.4         2.5947
# 14      388         CU 2017-04-22           70.9         2.5861
# 15      399         CU 2017-04-22           71.0         2.6888
# 16      410         CU 2017-04-22           72.6         2.7750
# 17      421         SI 2017-04-22           88.6         2.5530
# 18      432         SI 2017-04-22           86.7         2.7108
# 19      443         CU 2017-04-22           70.1         2.7510
# 20      454         SI 2017-04-22           88.9         2.4204
# 21      466         CU 2017-04-22           71.5         2.6049
# 22      478         CU 2017-04-22           71.2         2.5929
# 23      490         SI 2017-04-22           88.8         2.4875
# 24      502         SI 2017-04-22           88.8         2.7931
# 25      514         SI 2017-04-22           87.3         2.6255
# 26      526         SI 2017-04-22           88.1         2.5940
# 27      538         SI 2017-04-22           87.6         2.6184
# 28      550         SI 2017-04-22           88.2         2.7716
# 29      562         SI 2017-04-22           87.8         2.5778
# ...     ...        ...        ...            ...            ...
# 4374   3961         FT 2017-04-22           92.1         1.2297
# 4375   3982         FF 2017-04-22           92.4         1.2222
# 4376   3990         FT 2017-04-22           92.5         1.1775
# 4377   4008         FT 2017-04-22           92.1         1.2488
# 4378   4028         SL 2017-04-22           82.6         1.2006
# 4379   4041         FT 2017-04-22           91.3         1.3742
# 4380   4045         FF 2017-04-22           91.0         1.3034
# 4381   4067         CU 2017-04-22           75.7        -1.9308
# 4382   4087         SL 2017-04-22           83.0        -2.3147
# 4383   4090         FF 2017-04-22           88.1        -2.1537
# 4384   4114         CU 2017-04-22           76.7        -1.9988
# 4385   4126         CU 2017-04-22           74.4        -2.0476
# 4386   4141         FF 2017-04-22           92.0        -1.8951
# 4387   4149         SL 2017-04-22           84.8        -2.1072
# 4388   4175         SL 2017-04-22           84.0        -2.3556
# 4389   4181         FT 2017-04-22           90.5        -1.8647
# 4390   4199         CH 2017-04-22           85.5        -1.9201
# 4391   4209         FF 2017-04-22           91.0        -1.9407
# 4392   4237         CU 2017-04-22           76.5        -1.9554
# 4393   4245         FF 2017-04-22           90.8        -1.9059
# 4394   4258         FF 2017-04-22           90.7        -2.0914
# 4395   4278         FF 2017-04-22           90.5        -2.0025
# 4396   4291         FT 2017-04-22           91.2        -1.9591
# 4397   4307         FF 2017-04-22           92.2        -2.0857
# 4398   4318         SL 2017-04-22           83.7        -2.3005
# 4399   4332         FF 2017-04-22           89.1        -2.1791
# 4400   4354         FF 2017-04-22           90.1        -2.0541
# 4401   4368         FT 2017-04-22           89.9        -2.1270
# 4402   4388         FF 2017-04-22           89.7        -1.8382
# 4403   4394         FF 2017-04-22           90.3        -2.1145
#
#       release_pos_z     player_name    batter   pitcher       events  \
# 0            5.5364     Koda Glover  518595.0  606983.0    field_out
# 1            5.4235     Koda Glover  518595.0  606983.0          NaN
# 2            5.3670     Koda Glover  518595.0  606983.0          NaN
# 3            5.5062     Koda Glover  518595.0  606983.0          NaN
# 4            6.4911     Enny Romero  457803.0  544836.0    field_out
# 5            6.3707     Enny Romero  457803.0  544836.0          NaN
# 6            6.2301     Enny Romero  457803.0  544836.0          NaN
# 7            6.4793     Enny Romero  452678.0  544836.0    strikeout
# 8            6.3824     Enny Romero  452678.0  544836.0          NaN
# 9            6.4705     Enny Romero  452678.0  544836.0          NaN
# 10           5.2091   Jerry Blevins  502517.0  460283.0    strikeout
# 11           5.1544   Jerry Blevins  502517.0  460283.0          NaN
# 12           5.2785   Jerry Blevins  502517.0  460283.0          NaN
# 13           5.2893   Jerry Blevins  502517.0  460283.0          NaN
# 14           5.3365   Jerry Blevins  502517.0  460283.0          NaN
# 15           5.1770   Jerry Blevins  475582.0  460283.0         walk
# 16           5.2405   Jerry Blevins  475582.0  460283.0          NaN
# 17           5.2831   Jerry Blevins  475582.0  460283.0          NaN
# 18           5.1103   Jerry Blevins  475582.0  460283.0          NaN
# 19           5.1254   Jerry Blevins  475582.0  460283.0          NaN
# 20           5.4319   Jerry Blevins  475582.0  460283.0          NaN
# 21           5.0856   Jerry Blevins  547180.0  460283.0    strikeout
# 22           5.2778   Jerry Blevins  547180.0  460283.0          NaN
# 23           5.4833   Jerry Blevins  547180.0  460283.0          NaN
# 24           5.2221   Jerry Blevins  607208.0  460283.0  field_error
# 25           5.1982   Jerry Blevins  607208.0  460283.0          NaN
# 26           5.4144   Jerry Blevins  607208.0  460283.0          NaN
# 27           5.2259   Jerry Blevins  594809.0  460283.0    field_out
# 28           5.1807   Jerry Blevins  594809.0  460283.0          NaN
# 29           5.3373   Jerry Blevins  594809.0  460283.0          NaN
# ...             ...             ...       ...       ...          ...
# 4374         6.0004    Jaime Garcia  571437.0  448802.0          NaN
# 4375         5.9857    Jaime Garcia  514917.0  448802.0    field_out
# 4376         6.0316    Jaime Garcia  514917.0  448802.0          NaN
# 4377         6.0191    Jaime Garcia  514917.0  448802.0          NaN
# 4378         6.0369    Jaime Garcia  514917.0  448802.0          NaN
# 4379         6.0233    Jaime Garcia  514917.0  448802.0          NaN
# 4380         6.1624    Jaime Garcia  514917.0  448802.0          NaN
# 4381         6.2714  Jerad Eickhoff  455976.0  595191.0    strikeout
# 4382         5.8731  Jerad Eickhoff  455976.0  595191.0          NaN
# 4383         6.0790  Jerad Eickhoff  455976.0  595191.0          NaN
# 4384         6.2404  Jerad Eickhoff  455976.0  595191.0          NaN
# 4385         6.2152  Jerad Eickhoff  455976.0  595191.0          NaN
# 4386         6.1638  Jerad Eickhoff  461314.0  595191.0       single
# 4387         6.0000  Jerad Eickhoff  461314.0  595191.0          NaN
# 4388         5.9323  Jerad Eickhoff  461314.0  595191.0          NaN
# 4389         6.0848  Jerad Eickhoff  461314.0  595191.0          NaN
# 4390         6.2772  Jerad Eickhoff  461314.0  595191.0          NaN
# 4391         6.1337  Jerad Eickhoff  518692.0  595191.0         walk
# 4392         6.2139  Jerad Eickhoff  518692.0  595191.0          NaN
# 4393         6.1504  Jerad Eickhoff  518692.0  595191.0          NaN
# 4394         5.9688  Jerad Eickhoff  518692.0  595191.0          NaN
# 4395         6.1085  Jerad Eickhoff  518692.0  595191.0          NaN
# 4396         6.0410  Jerad Eickhoff  611177.0  595191.0    field_out
# 4397         6.0103  Jerad Eickhoff  611177.0  595191.0          NaN
# 4398         5.9976  Jerad Eickhoff  611177.0  595191.0          NaN
# 4399         5.9762  Jerad Eickhoff  611177.0  595191.0          NaN
# 4400         6.1036  Jerad Eickhoff  611177.0  595191.0          NaN
# 4401         6.0218  Jerad Eickhoff  611177.0  595191.0          NaN
# 4402         6.2084  Jerad Eickhoff  611177.0  595191.0          NaN
# 4403         6.1476  Jerad Eickhoff  542255.0  595191.0    field_out
#
#          ...      release_pos_y  estimated_ba_using_speedangle  \
# 0        ...            54.5374                          0.235
# 1        ...            54.5110                          0.000
# 2        ...            54.6146                          0.000
# 3        ...            54.4553                          0.000
# 4        ...            55.1990                          0.009
# 5        ...            54.8051                          0.000
# 6        ...            55.1727                          0.000
# 7        ...            55.2136                          0.000
# 8        ...            54.8739                          0.000
# 9        ...            55.1266                          0.000
# 10       ...            54.9504                          0.000
# 11       ...            54.4006                          0.000
# 12       ...            54.1210                          0.000
# 13       ...            53.8604                          0.000
# 14       ...            54.4430                          0.000
# 15       ...            54.5760                          0.000
# 16       ...            54.4195                          0.000
# 17       ...            53.8900                          0.000
# 18       ...            53.7858                          0.000
# 19       ...            55.0995                          0.000
# 20       ...            54.1531                          0.000
# 21       ...            53.9202                          0.000
# 22       ...            54.5545                          0.000
# 23       ...            54.2518                          0.000
# 24       ...            54.2172                          0.408
# 25       ...            54.1333                          0.000
# 26       ...            53.9283                          0.000
# 27       ...            54.1274                          0.016
# 28       ...            54.2332                          0.000
# 29       ...            54.2740                          0.000
# ...      ...                ...                            ...
# 4374     ...            54.4877                          0.000
# 4375     ...            54.3439                          0.050
# 4376     ...            54.4781                          0.000
# 4377     ...            54.6779                          0.000
# 4378     ...            55.1792                          0.000
# 4379     ...            54.6002                          0.000
# 4380     ...            54.6536                          0.000
# 4381     ...            54.5784                          0.000
# 4382     ...            54.2804                          0.000
# 4383     ...            54.2403                          0.000
# 4384     ...            54.9181                          0.000
# 4385     ...            54.7937                          0.000
# 4386     ...            54.2492                          0.563
# 4387     ...            54.4359                          0.000
# 4388     ...            54.4786                          0.000
# 4389     ...            53.8140                          0.000
# 4390     ...            54.8182                          0.000
# 4391     ...            54.3582                          0.000
# 4392     ...            54.7964                          0.000
# 4393     ...            54.0696                          0.000
# 4394     ...            54.2926                          0.000
# 4395     ...            54.2872                          0.000
# 4396     ...            54.1207                          0.648
# 4397     ...            54.1824                          0.000
# 4398     ...            54.6501                          0.000
# 4399     ...            53.9381                          0.000
# 4400     ...            53.9510                          0.000
# 4401     ...            54.4490                          0.000
# 4402     ...            54.0653                          0.000
# 4403     ...            54.4071                          0.669
#
#       estimated_woba_using_speedangle  woba_value  woba_denom  babip_value  \
# 0                               0.342         0.0         1.0          0.0
# 1                               0.000         NaN         NaN          NaN
# 2                               0.000         NaN         NaN          NaN
# 3                               0.000         NaN         NaN          NaN
# 4                               0.009         0.0         1.0          0.0
# 5                               0.000         NaN         NaN          NaN
# 6                               0.000         NaN         NaN          NaN
# 7                               0.000         0.0         1.0          0.0
# 8                               0.000         NaN         NaN          NaN
# 9                               0.000         NaN         NaN          NaN
# 10                              0.000         0.0         1.0          0.0
# 11                              0.000         NaN         NaN          NaN
# 12                              0.000         NaN         NaN          NaN
# 13                              0.000         NaN         NaN          NaN
# 14                              0.000         NaN         NaN          NaN
# 15                              0.000         0.7         1.0          0.0
# 16                              0.000         NaN         NaN          NaN
# 17                              0.000         NaN         NaN          NaN
# 18                              0.000         NaN         NaN          NaN
# 19                              0.000         NaN         NaN          NaN
# 20                              0.000         NaN         NaN          NaN
# 21                              0.000         0.0         1.0          0.0
# 22                              0.000         NaN         NaN          NaN
# 23                              0.000         NaN         NaN          NaN
# 24                              0.376         0.0         1.0          0.0
# 25                              0.000         NaN         NaN          NaN
# 26                              0.000         NaN         NaN          NaN
# 27                              0.016         0.0         1.0          0.0
# 28                              0.000         NaN         NaN          NaN
# 29                              0.000         NaN         NaN          NaN
# ...                               ...         ...         ...          ...
# 4374                            0.000         NaN         NaN          NaN
# 4375                            0.048         0.0         1.0          0.0
# 4376                            0.000         NaN         NaN          NaN
# 4377                            0.000         NaN         NaN          NaN
# 4378                            0.000         NaN         NaN          NaN
# 4379                            0.000         NaN         NaN          NaN
# 4380                            0.000         NaN         NaN          NaN
# 4381                            0.000         0.0         1.0          0.0
# 4382                            0.000         NaN         NaN          NaN
# 4383                            0.000         NaN         NaN          NaN
# 4384                            0.000         NaN         NaN          NaN
# 4385                            0.000         NaN         NaN          NaN
# 4386                            0.529         0.9         1.0          1.0
# 4387                            0.000         NaN         NaN          NaN
# 4388                            0.000         NaN         NaN          NaN
# 4389                            0.000         NaN         NaN          NaN
# 4390                            0.000         NaN         NaN          NaN
# 4391                            0.000         0.7         1.0          0.0
# 4392                            0.000         NaN         NaN          NaN
# 4393                            0.000         NaN         NaN          NaN
# 4394                            0.000         NaN         NaN          NaN
# 4395                            0.000         NaN         NaN          NaN
# 4396                            0.599         0.0         1.0          0.0
# 4397                            0.000         NaN         NaN          NaN
# 4398                            0.000         NaN         NaN          NaN
# 4399                            0.000         NaN         NaN          NaN
# 4400                            0.000         NaN         NaN          NaN
# 4401                            0.000         NaN         NaN          NaN
# 4402                            0.000         NaN         NaN          NaN
# 4403                            0.982         0.0         1.0          0.0
#
#      iso_value launch_speed_angle at_bat_number pitch_number
# 0          0.0                3.0          73.0          4.0
# 1          NaN                NaN          73.0          3.0
# 2          NaN                NaN          73.0          2.0
# 3          NaN                NaN          73.0          1.0
# 4          0.0                3.0          72.0          3.0
# 5          NaN                NaN          72.0          2.0
# 6          NaN                NaN          72.0          1.0
# 7          0.0                NaN          71.0          3.0
# 8          NaN                NaN          71.0          2.0
# 9          NaN                NaN          71.0          1.0
# 10         0.0                NaN          70.0          5.0
# 11         NaN                NaN          70.0          4.0
# 12         NaN                NaN          70.0          3.0
# 13         NaN                NaN          70.0          2.0
# 14         NaN                NaN          70.0          1.0
# 15         0.0                NaN          69.0          6.0
# 16         NaN                NaN          69.0          5.0
# 17         NaN                NaN          69.0          4.0
# 18         NaN                NaN          69.0          3.0
# 19         NaN                NaN          69.0          2.0
# 20         NaN                NaN          69.0          1.0
# 21         0.0                NaN          68.0          3.0
# 22         NaN                NaN          68.0          2.0
# 23         NaN                NaN          68.0          1.0
# 24         0.0                2.0          67.0          3.0
# 25         NaN                NaN          67.0          2.0
# 26         NaN                NaN          67.0          1.0
# 27         0.0                3.0          66.0          7.0
# 28         NaN                NaN          66.0          6.0
# 29         NaN                NaN          66.0          5.0
# ...        ...                ...           ...          ...
# 4374       NaN                NaN           7.0          1.0
# 4375       0.0                2.0           6.0          6.0
# 4376       NaN                NaN           6.0          5.0
# 4377       NaN                NaN           6.0          4.0
# 4378       NaN                NaN           6.0          3.0
# 4379       NaN                NaN           6.0          2.0
# 4380       NaN                NaN           6.0          1.0
# 4381       0.0                NaN           5.0          5.0
# 4382       NaN                NaN           5.0          4.0
# 4383       NaN                NaN           5.0          3.0
# 4384       NaN                NaN           5.0          2.0
# 4385       NaN                NaN           5.0          1.0
# 4386       0.0                4.0           4.0          5.0
# 4387       NaN                2.0           4.0          4.0
# 4388       NaN                NaN           4.0          3.0
# 4389       NaN                NaN           4.0          2.0
# 4390       NaN                NaN           4.0          1.0
# 4391       0.0                NaN           3.0          5.0
# 4392       NaN                NaN           3.0          4.0
# 4393       NaN                NaN           3.0          3.0
# 4394       NaN                NaN           3.0          2.0
# 4395       NaN                NaN           3.0          1.0
# 4396       0.0                4.0           2.0          7.0
# 4397       NaN                NaN           2.0          6.0
# 4398       NaN                1.0           2.0          5.0
# 4399       NaN                NaN           2.0          4.0
# 4400       NaN                NaN           2.0          3.0
# 4401       NaN                NaN           2.0          2.0
# 4402       NaN                NaN           2.0          1.0
# 4403       0.0                5.0           1.0          1.0
#
# [4404 rows x 79 columns]

# %%
data.drop('index', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-908f00df2420> in <module>()
# ----> 1 data.drop('index', inplace=True)
#
# /Users/michaellucas/PycharmProjects/sportscraper/venv/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /Users/michaellucas/PycharmProjects/sportscraper/venv/lib/python2.7/site-packages/pandas/core/generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# /Users/michaellucas/PycharmProjects/sportscraper/venv/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels ['index'] not contained in axis

# %%
engine = create_engine("mysql+mysqldb://root:" + 'root' + "@127.0.0.1/baseball")
meta = MetaData(bind=engine)

# %%
for key, value in data.dtypes.to_dict().iteritems():
    print str('Column("' + str(key) + '", ' + str(value) + ', nullable=True),')
# Out:
# Column("sz_bot", float64, nullable=True),
# Column("inning", float64, nullable=True),
# Column("pitch_number", float64, nullable=True),
# Column("hit_distance_sc", float64, nullable=True),
# Column("plate_z", float64, nullable=True),
# Column("plate_x", float64, nullable=True),
# Column("umpire", float64, nullable=True),
# Column("pitch_type", object, nullable=True),
# Column("spin_rate_deprecated", float64, nullable=True),
# Column("pos8_person_id", float64, nullable=True),
# Column("pos6_person_id", float64, nullable=True),
# Column("pos2_person_id.1", float64, nullable=True),
# Column("on_3b", float64, nullable=True),
# Column("release_pos_y", float64, nullable=True),
# Column("pos2_person_id", float64, nullable=True),
# Column("launch_speed", float64, nullable=True),
# Column("ay", float64, nullable=True),
# Column("ax", float64, nullable=True),
# Column("az", float64, nullable=True),
# Column("p_throws", object, nullable=True),
# Column("release_speed", float64, nullable=True),
# Column("break_length_deprecated", float64, nullable=True),
# Column("at_bat_number", float64, nullable=True),
# Column("index", int64, nullable=True),
# Column("vy0", float64, nullable=True),
# Column("away_team", object, nullable=True),
# Column("player_name", object, nullable=True),
# Column("zone", float64, nullable=True),
# Column("pos7_person_id", float64, nullable=True),
# Column("babip_value", float64, nullable=True),
# Column("bb_type", object, nullable=True),
# Column("release_spin_rate", float64, nullable=True),
# Column("effective_speed", float64, nullable=True),
# Column("pos3_person_id", float64, nullable=True),
# Column("hc_y", float64, nullable=True),
# Column("inning_topbot", object, nullable=True),
# Column("release_extension", float64, nullable=True),
# Column("on_1b", float64, nullable=True),
# Column("pos1_person_id", float64, nullable=True),
# Column("hit_location", float64, nullable=True),
# Column("release_pos_x", float64, nullable=True),
# Column("events", object, nullable=True),
# Column("release_pos_z", float64, nullable=True),
# Column("game_year", float64, nullable=True),
# Column("pos4_person_id", float64, nullable=True),
# Column("woba_value", float64, nullable=True),
# Column("description", object, nullable=True),
# Column("pfx_z", float64, nullable=True),
# Column("launch_angle", float64, nullable=True),
# Column("pitcher", float64, nullable=True),
# Column("strikes", float64, nullable=True),
# Column("pos9_person_id", float64, nullable=True),
# Column("batter", float64, nullable=True),
# Column("pfx_x", float64, nullable=True),
# Column("hc_x", float64, nullable=True),
# Column("on_2b", float64, nullable=True),
# Column("game_pk", float64, nullable=True),
# Column("spin_dir", float64, nullable=True),
# Column("iso_value", float64, nullable=True),
# Column("woba_denom", float64, nullable=True),
# Column("home_team", object, nullable=True),
# Column("balls", float64, nullable=True),
# Column("estimated_ba_using_speedangle", float64, nullable=True),
# Column("estimated_woba_using_speedangle", float64, nullable=True),
# Column("type", object, nullable=True),
# Column("tfs_deprecated", float64, nullable=True),
# Column("des", object, nullable=True),
# Column("game_type", object, nullable=True),
# Column("outs_when_up", float64, nullable=True),
# Column("vx0", float64, nullable=True),
# Column("sz_top", float64, nullable=True),
# Column("launch_speed_angle", float64, nullable=True),
# Column("stand", object, nullable=True),
# Column("game_date", datetime64[ns], nullable=True),
# Column("break_angle_deprecated", float64, nullable=True),
# Column("vz0", float64, nullable=True),
# Column("sv_id", object, nullable=True),
# Column("tfs_zulu_deprecated", float64, nullable=True),
# Column("pos5_person_id", float64, nullable=True),

# %%
table_statcast = Table('statcast', meta,
     Column("id", Integer, primary_key=True, autoincrement=True, nullable=False),
     Column("index", Integer, nullable=True),
     Column("sz_bot", Integer, nullable=True),
     Column("inning", Integer, nullable=True),
     Column("pitch_number", Integer, nullable=True),
     Column("hit_distance_sc", Integer, nullable=True),
     Column("plate_z", Integer, nullable=True),
     Column("plate_x", Integer, nullable=True),
     Column("umpire", Integer, nullable=True),
     Column("pitch_type", String(512), nullable=True),
     Column("spin_rate_deprecated", Integer, nullable=True),
     Column("pos8_person_id", Integer, nullable=True),
     Column("pos6_person_id", Integer, nullable=True),
     Column("pos2_person_id.1", Integer, nullable=True),
     Column("on_3b", Integer, nullable=True),
     Column("release_pos_y", Integer, nullable=True),
     Column("pos2_person_id", Integer, nullable=True),
     Column("launch_speed", Integer, nullable=True),
     Column("ay", Integer, nullable=True),
     Column("ax", Integer, nullable=True),
     Column("az", Integer, nullable=True),
     Column("p_throws", String(512), nullable=True),
     Column("release_speed", Integer, nullable=True),
     Column("break_length_deprecated", Integer, nullable=True),
     Column("at_bat_number", Integer, nullable=True),
     Column("vy0", Integer, nullable=True),
     Column("away_team", String(512), nullable=True),
     Column("player_name", String(512), nullable=True),
     Column("zone", Integer, nullable=True),
     Column("pos7_person_id", Integer, nullable=True),
     Column("babip_value", Integer, nullable=True),
     Column("bb_type", String(512), nullable=True),
     Column("release_spin_rate", Integer, nullable=True),
     Column("effective_speed", Integer, nullable=True),
     Column("pos3_person_id", Integer, nullable=True),
     Column("hc_y", Integer, nullable=True),
     Column("inning_topbot", String(512), nullable=True),
     Column("release_extension", Integer, nullable=True),
     Column("on_1b", Integer, nullable=True),
     Column("pos1_person_id", Integer, nullable=True),
     Column("hit_location", Integer, nullable=True),
     Column("release_pos_x", Integer, nullable=True),
     Column("events", String(512), nullable=True),
     Column("release_pos_z", Integer, nullable=True),
     Column("game_year", Integer, nullable=True),
     Column("pos4_person_id", Integer, nullable=True),
     Column("woba_value", Integer, nullable=True),
     Column("description", String(512), nullable=True),
     Column("pfx_z", Integer, nullable=True),
     Column("launch_angle", Integer, nullable=True),
     Column("pitcher", Integer, nullable=True),
     Column("strikes", Integer, nullable=True),
     Column("pos9_person_id", Integer, nullable=True),
     Column("batter", Integer, nullable=True),
     Column("pfx_x", Integer, nullable=True),
     Column("hc_x", Integer, nullable=True),
     Column("on_2b", Integer, nullable=True),
     Column("game_pk", Integer, nullable=True),
     Column("spin_dir", Integer, nullable=True),
     Column("iso_value", Integer, nullable=True),
     Column("woba_denom", Integer, nullable=True),
     Column("home_team", String(512), nullable=True),
     Column("balls", Integer, nullable=True),
     Column("estimated_ba_using_speedangle", Integer, nullable=True),
     Column("estimated_woba_using_speedangle", Integer, nullable=True),
     Column("type", String(512), nullable=True),
     Column("tfs_deprecated", Integer, nullable=True),
     Column("des", String(512), nullable=True),
     Column("game_type", String(512), nullable=True),
     Column("outs_when_up", Integer, nullable=True),
     Column("vx0", Integer, nullable=True),
     Column("sz_top", Integer, nullable=True),
     Column("launch_speed_angle", Integer, nullable=True),
     Column("stand", String(512), nullable=True),
     Column("game_date", DateTime, nullable=True),
     Column("break_angle_deprecated", Integer, nullable=True),
     Column("vz0", Integer, nullable=True),
     Column("sv_id", String(512), nullable=True),
     Column("tfs_zulu_deprecated", Integer, nullable=True),
     Column("pos5_person_id", Integer, nullable=True), extend_existing=True)

# %%
meta.create_all(engine)

# %%
data.to_sql('statcast', con=engine, if_exists='append', index=False)
